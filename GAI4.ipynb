# %%
from transformers import BlipProcessor, BlipForConditionalGeneration
from PIL import Image
import matplotlib.pyplot as plt

image = Image.open("SU30.jpeg").convert('RGB')

processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")

inputs = processor(images=image, return_tensors="pt")
out = model.generate(**inputs, max_length=50)
caption = processor.decode(out[0], skip_special_tokens=True)

print("Generated Caption:", caption)

plt.imshow(image)
plt.title(caption)
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\rathi\AppData\Local\Programs\Python\Python39\lib\site-packages\transformers\utils\import_utils.py:1967, in _LazyModule._get_module(self, module_name)
#    1966 try:
# -> 1967     return importlib.import_module("." + module_name, self.__name__)
#    1968 except Exception as e:
#
# File c:\Users\rathi\AppData\Local\Programs\Python\Python39\lib\importlib\__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:850, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\Users\rathi\AppData\Local\Programs\Python\Python39\lib\site-packages\transformers\models\blip\processing_blip.py:21
#      19 from typing import List, Optional, Union
# ---> 21 from ...image_utils import ImageInput
#      22 from ...processing_utils import ProcessingKwargs, ProcessorMixin, Unpack
#
# File c:\Users\rathi\AppData\Local\Programs\Python\Python39\lib\site-packages\transformers\image_utils.py:64
#      63 if is_torchvision_available():
# ---> 64     from torchvision import io as torchvision_io
#      65     from torchvision.transforms import InterpolationMode
#
# File c:\Users\rathi\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\__init__.py:10
#       9 from .extension import _HAS_OPS  # usort:skip
# ---> 10 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils  # usort:skip
#      12 try:
#
# File c:\Users\rathi\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\models\__init__.py:2
#       1 from .alexnet import *
# ----> 2 from .convnext import *
#       3 from .densenet import *
#
# File c:\Users\rathi\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\models\convnext.py:9
#       8 from ..ops.misc import Conv2dNormActivation, Permute
# ----> 9 from ..ops.stochastic_depth import StochasticDepth
#      10 from ..transforms._presets import ImageClassification
#
# File c:\Users\rathi\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\ops\__init__.py:23
#      22 from .misc import Conv2dNormActivation, Conv3dNormActivation, FrozenBatchNorm2d, MLP, Permute, SqueezeExcitation
# ---> 23 from .poolers import MultiScaleRoIAlign
#      24 from .ps_roi_align import ps_roi_align, PSRoIAlign
#
# File c:\Users\rathi\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\ops\poolers.py:10
#       9 from ..utils import _log_api_usage_once
# ---> 10 from .roi_align import roi_align
#      13 # copying result_idx_in_level to a specific index in result[]
#      14 # is not supported by ONNX tracing yet.
#      15 # _onnx_merge_levels() is an implementation supported by ONNX
#      16 # that merges the levels to the right indices
#
# File c:\Users\rathi\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\ops\roi_align.py:7
#       6 from torch import nn, Tensor
# ----> 7 from torch._dynamo.utils import is_compile_supported
#       8 from torch.jit.annotations import BroadcastingList2
#
# File c:\Users\rathi\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\__init__.py:13
#      11 import torch
# ---> 13 from . import config, convert_frame, eval_frame, resume_execution
#      14 from .backends.registry import list_backends, lookup_backend, register_backend
#
# File c:\Users\rathi\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\convert_frame.py:52
#      51 from torch._dynamo.distributed import get_compile_pg
# ---> 52 from torch._dynamo.symbolic_convert import TensorifyState
#      53 from torch._guards import compile_context, CompileContext, CompileId, tracing
#
# File c:\Users\rathi\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\symbolic_convert.py:52
#      51 import torch._logging
# ---> 52 from torch._dynamo.exc import TensorifyScalarRestartAnalysis
#      53 from torch._guards import tracing, TracingContext
#
# File c:\Users\rathi\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\exc.py:41
#      40 from . import config
# ---> 41 from .utils import counters
#      44 if TYPE_CHECKING:
#
# File c:\Users\rathi\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\utils.py:69
#      68 import torch._functorch.config
# ---> 69 import torch.fx.experimental.symbolic_shapes
#      70 import torch.utils._pytree as pytree
#
# File c:\Users\rathi\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\fx\experimental\symbolic_shapes.py:67
#      66 from torch.utils._python_dispatch import is_traceable_wrapper_subclass
# ---> 67 from torch.utils._sympy.functions import (
#      68     Application,
#      69     CeilToInt,
#      70     CleanDiv,
#      71     FloorDiv,
#      72     FloorToInt,
#      73     IsNonOverlappingAndDenseIndicator,
#      74     Max,
#      75     Mod,
#      76     PythonMod,
#      77 )
#      78 from torch.utils._sympy.numbers import int_oo
#
# File c:\Users\rathi\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\utils\_sympy\functions.py:183
#     165 # It would be nice to have assertions on whether or not inputs is_integer
#     166 # However, with bugs like https://github.com/sympy/sympy/issues/26620 sympy
#     167 # sometimes inconsistently reports floats an integers.
#    (...)
#     181 # Right now, FloorDiv de facto changes behavior if arguments are negative or
#     182 # not, this can potentially cause correctness issues.
# --> 183 class FloorDiv(sympy.Function):
#     184     """
#     185     We maintain this so that:
#     186     1. We can use divisibility guards to simplify FloorDiv(a, b) to a / b.
#    (...)
#     189     NB: This is Python-style floor division, round to -Inf
#     190     """
#
# File c:\Users\rathi\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\utils\_sympy\functions.py:204, in FloorDiv()
#     202     return self.args[1]
# --> 204 def _sympystr(self, printer: sympy.printing.StrPrinter) -> str:
#     205     base = printer.parenthesize(self.base, PRECEDENCE["Atom"] - 0.5)
#
# AttributeError: module 'sympy' has no attribute 'printing'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from transformers import BlipProcessor, BlipForConditionalGeneration
#       2 from PIL import Image
#       3 import matplotlib.pyplot as plt
#
# File <frozen importlib._bootstrap>:1055, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\rathi\AppData\Local\Programs\Python\Python39\lib\site-packages\transformers\utils\import_utils.py:1956, in _LazyModule.__getattr__(self, name)
#    1954 elif name in self._class_to_module.keys():
#    1955     module = self._get_module(self._class_to_module[name])
# -> 1956     value = getattr(module, name)
#    1957 elif name in self._modules:
#    1958     value = self._get_module(name)
#
# File c:\Users\rathi\AppData\Local\Programs\Python\Python39\lib\site-packages\transformers\utils\import_utils.py:1955, in _LazyModule.__getattr__(self, name)
#    1953     value = Placeholder
#    1954 elif name in self._class_to_module.keys():
# -> 1955     module = self._get_module(self._class_to_module[name])
#    1956     value = getattr(module, name)
#    1957 elif name in self._modules:
#
# File c:\Users\rathi\AppData\Local\Programs\Python\Python39\lib\site-packages\transformers\utils\import_utils.py:1969, in _LazyModule._get_module(self, module_name)
#    1967     return importlib.import_module("." + module_name, self.__name__)
#    1968 except Exception as e:
# -> 1969     raise RuntimeError(
#    1970         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1971         f" traceback):\n{e}"
#    1972     ) from e
#
# RuntimeError: Failed to import transformers.models.blip.processing_blip because of the following error (look up to see its traceback):
# module 'sympy' has no attribute 'printing'
